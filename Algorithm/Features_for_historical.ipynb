# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
df = pd.read_excel("combined_data.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_excel("combined_data.csv")
#
# File c:\file_struct\programs\python\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File c:\file_struct\programs\python\Lib\site-packages\pandas\io\excel\_base.py:1554, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
# -> 1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#    1559 engine = config.get_option(f"io.excel.{ext}.reader", silent=True)
#    1560 if engine == "auto":
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.

# %%
df['Date'] =pd.to_datetime(df['Date'])
df = df.sort_values(['Ticker','Date'])

# %%
df['MA_5'] =df.groupby('Ticker')['Close'].transform(
    lambda x: x.rolling(window=5, min_periods=1).mean()
)

# %%
print(df[['Date', 'Ticker','Close','MA_5']].head(10))

# %%
def create_features(df):
  group = df.copy()
  group['MA5'] =group.groupby('Ticker')['Close'].transform(
      lambda x: x.rolling(window=5, min_periods=1).mean()
  )

  group['Daily_Return'] = group.groupby('Ticker')['Close'].transform(
      lambda x: x.pct_change())

  return group

# %%
df_with_features = df.groupby('Ticker')[df.columns].apply(create_features)
df_with_features.dropna(inplace=True)
df_with_features.reset_index(drop=True, inplace=True)
df_with_features.head()
